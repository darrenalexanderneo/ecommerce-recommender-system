# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_excel('Sample 5000.xlsx')
data
# Out:
#                     event_time event_type  product_id   category_id  \
# 0      2019-10-01 08:47:35 UTC       view     1001588  2.053010e+18
# 1      2019-10-01 08:47:35 UTC       view     1001588  2.053014e+18
# 2      2019-10-01 08:48:28 UTC       view     1003535  2.053014e+18
# 3      2019-10-01 17:06:51 UTC       view     4100129  2.053014e+18
# 4      2019-10-01 16:48:28 UTC       view     6400036  2.053014e+18
# ...                        ...        ...         ...           ...
# 9997   2019-10-01 16:09:57 UTC       view     6701210  2.053014e+18
# 9998   2019-10-01 16:10:50 UTC       view     6701210  2.053014e+18
# 9999   2019-10-01 11:12:38 UTC       view     3900217  2.053014e+18
# 10000  2019-10-01 11:13:30 UTC       view     1005067  2.053014e+18
# 10001  2019-10-01 11:13:43 UTC       view     1005074  2.053014e+18
#
#                              category_code      brand    price    user_id  \
# 0                   electronics.smartphone    samsung   460.50  244951053
# 1                   electronics.smartphone    samsung   460.50  244951053
# 2                   electronics.smartphone    samsung   460.50  244951053
# 3                                      NaN       sony   463.02  292071852
# 4                 computers.components.cpu      intel   338.23  295655799
# ...                                    ...        ...      ...        ...
# 9997       computers.components.videocards        msi   939.03  512393615
# 9998       computers.components.videocards        msi   939.03  512393615
# 9999   appliances.environment.water_heater  garanterm    90.32  512393698
# 10000               electronics.smartphone    samsung  1209.53  512393698
# 10001               electronics.smartphone    samsung  1235.24  512393698
#
#                                user_session  interaction
# 0      91769fdf-461b-4e43-9c73-88a07481b75c            1
# 1      91769fdf-461b-4e43-9c73-88a07481b75c            1
# 2      91769fdf-461b-4e43-9c73-88a07481b75c            1
# 3      0051531b-c007-442f-88c8-2cbf9537bd02            1
# 4      eb8f2cea-4c5b-4e00-880f-3bcfa28549ff            1
# ...                                     ...          ...
# 9997   6b08f33f-53fa-431d-99f6-b06c9b10d6af            1
# 9998   6b08f33f-53fa-431d-99f6-b06c9b10d6af            1
# 9999   bac58664-4b1f-414f-a914-afb0caceae36            1
# 10000  39b68180-94ba-4615-85a8-f8b76f6a84af            1
# 10001  39b68180-94ba-4615-85a8-f8b76f6a84af            1
#
# [10002 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_time     10002 non-null  object
#  1   event_type     10002 non-null  object
#  2   product_id     10002 non-null  int64
#  3   category_id    10002 non-null  float64
#  4   category_code  6624 non-null   object
#  5   brand          8596 non-null   object
#  6   price          10002 non-null  float64
#  7   user_id        10002 non-null  int64
#  8   user_session   10002 non-null  object
#  9   interaction    10002 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 781.5+ KB

# %%
data.describe()
# Out:
#          product_id   category_id         price       user_id  interaction
# count  1.000200e+04  1.000200e+04  10002.000000  1.000200e+04      10002.0
# mean   1.068298e+07  2.056788e+18    290.804285  4.953594e+08          1.0
# std    1.141440e+07  1.690812e+16    360.862538  2.930729e+07          0.0
# min    1.001588e+06  2.053010e+18      0.000000  2.449511e+08          1.0
# 25%    1.201357e+06  2.053014e+18     62.290000  4.886695e+08          1.0
# 50%    5.100816e+06  2.053014e+18    161.930000  5.123637e+08          1.0
# 75%    1.710029e+07  2.053014e+18    358.822500  5.123790e+08          1.0
# max    5.390001e+07  2.172371e+18   2574.070000  5.123937e+08          1.0

# %%
data.nunique()
# Out:
# event_time       9076
# event_type          3
# product_id       4246
# category_id       341
# category_code      99
# brand             656
# price            2862
# user_id          1732
# user_session     2512
# interaction         1
# dtype: int64

# %%
data.isnull().sum()
# Out:
# event_time          0
# event_type          0
# product_id          0
# category_id         0
# category_code    3378
# brand            1406
# price               0
# user_id             0
# user_session        0
# interaction         0
# dtype: int64

# %%
data['product_id'].value_counts()
# Out:
# 1004856     111
# 1004767      84
# 1005115      55
# 1005105      54
# 1002544      53
#            ...
# 2502139       1
# 28100772      1
# 1004142       1
# 18000158      1
# 3900217       1
# Name: product_id, Length: 4246, dtype: int64

# %%
data['user_id'].value_counts()
# Out:
# 512372746    99
# 512377508    98
# 512367874    82
# 512390127    75
# 463570586    74
#              ..
# 483067155     1
# 482644772     1
# 482527581     1
# 512368877     1
# 479112986     1
# Name: user_id, Length: 1732, dtype: int64

# %%
popularproducts=pd.DataFrame(data)

# %%
popular_products = pd.DataFrame(data.groupby("product_id").count()['user_id'].sort_values(ascending=False))
popular_products.rename(columns={"product_id": "count"})
popular_products
# Out:
#             user_id
# product_id
# 1004856         111
# 1004767          84
# 1005115          55
# 1005105          54
# 1002544          53
# ...             ...
# 11200451          1
# 11200504          1
# 11200505          1
# 11400099          1
# 53900007          1
#
# [4246 rows x 1 columns]

# %%
popular_products.head(30).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='product_id'>

# %%
product_matrix=data.pivot_table(index="user_id",columns='product_id',values="interaction",fill_value=0)
product_matrix
# Out:
# product_id  1001588   1002099   1002101   1002102   1002367   1002398   \
# user_id
# 244951053          1         0         0         0         0         0
# 292071852          0         0         0         0         0         0
# 295655799          0         0         0         0         0         0
# 306087674          0         0         0         0         0         0
# 306441847          0         0         0         0         0         0
# ...              ...       ...       ...       ...       ...       ...
# 512393480          0         0         0         0         0         0
# 512393542          0         0         0         0         0         0
# 512393581          0         0         0         0         0         0
# 512393615          0         0         0         0         0         0
# 512393698          0         0         0         0         0         0
#
# product_id  1002482   1002484   1002524   1002532   ...  52900003  52900013  \
# user_id                                             ...
# 244951053          0         0         0         0  ...         0         0
# 292071852          0         0         0         0  ...         0         0
# 295655799          0         0         0         0  ...         0         0
# 306087674          0         0         0         0  ...         0         0
# 306441847          0         0         0         0  ...         0         0
# ...              ...       ...       ...       ...  ...       ...       ...
# 512393480          0         0         0         0  ...         0         0
# 512393542          0         0         0         0  ...         0         0
# 512393581          0         0         0         0  ...         0         0
# 512393615          0         0         0         0  ...         0         0
# 512393698          0         0         0         0  ...         0         0
#
# product_id  52900025  52900026  52900038  52900039  52900050  52900077  \
# user_id
# 244951053          0         0         0         0         0         0
# 292071852          0         0         0         0         0         0
# 295655799          0         0         0         0         0         0
# 306087674          0         0         0         0         0         0
# 306441847          0         0         0         0         0         0
# ...              ...       ...       ...       ...       ...       ...
# 512393480          0         0         0         0         0         0
# 512393542          0         0         0         0         0         0
# 512393581          0         0         0         0         0         0
# 512393615          0         0         0         0         0         0
# 512393698          0         0         0         0         0         0
#
# product_id  52900079  53900007
# user_id
# 244951053          0         0
# 292071852          0         0
# 295655799          0         0
# 306087674          0         0
# 306441847          0         0
# ...              ...       ...
# 512393480          0         0
# 512393542          0         0
# 512393581          0         0
# 512393615          0         0
# 512393698          0         0
#
# [1732 rows x 4246 columns]

# %%
product_matrix.shape
# Out:
# (1732, 4246)

# %%
product_matrix.query('user_id ==512367874').sum(axis=1)
# Out:
# user_id
# 512367874    24
# dtype: int64

# %%
product_matrix=product_matrix.T
product_matrix
# Out:
# user_id     244951053  292071852  295655799  306087674  306441847  315309190  \
# product_id
# 1001588             1          0          0          0          0          0
# 1002099             0          0          0          0          0          0
# 1002101             0          0          0          0          0          0
# 1002102             0          0          0          0          0          0
# 1002367             0          0          0          0          0          0
# ...               ...        ...        ...        ...        ...        ...
# 52900039            0          0          0          0          0          0
# 52900050            0          0          0          0          0          0
# 52900077            0          0          0          0          0          0
# 52900079            0          0          0          0          0          0
# 53900007            0          0          0          0          0          0
#
# user_id     315805600  318145786  321655812  330585300  ...  512393171  \
# product_id                                              ...
# 1001588             0          0          0          0  ...          0
# 1002099             0          0          0          0  ...          0
# 1002101             0          0          0          0  ...          0
# 1002102             0          0          0          0  ...          0
# 1002367             0          0          0          0  ...          0
# ...               ...        ...        ...        ...  ...        ...
# 52900039            0          0          0          0  ...          0
# 52900050            0          0          0          0  ...          0
# 52900077            0          0          0          0  ...          0
# 52900079            0          0          0          0  ...          0
# 53900007            0          0          0          0  ...          0
#
# user_id     512393323  512393343  512393366  512393426  512393480  512393542  \
# product_id
# 1001588             0          0          0          0          0          0
# 1002099             0          0          0          0          0          0
# 1002101             0          0          0          0          0          0
# 1002102             0          0          0          0          0          0
# 1002367             0          0          0          0          0          0
# ...               ...        ...        ...        ...        ...        ...
# 52900039            0          0          0          0          0          0
# 52900050            0          0          0          0          0          0
# 52900077            0          0          0          0          0          0
# 52900079            0          0          0          0          0          0
# 53900007            0          0          0          0          0          0
#
# user_id     512393581  512393615  512393698
# product_id
# 1001588             0          0          0
# 1002099             0          0          0
# 1002101             0          0          0
# 1002102             0          0          0
# 1002367             0          0          0
# ...               ...        ...        ...
# 52900039            0          0          0
# 52900050            0          0          0
# 52900077            0          0          0
# 52900079            0          0          0
# 53900007            0          0          0
#
# [4246 rows x 1732 columns]

# %%
product_matrix.shape
# Out:
# (4246, 1732)

# %%
import sklearn
from sklearn.decomposition import TruncatedSVD
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(product_matrix)
decomposed_matrix.shape
# Out:
# (4246, 10)

# %%
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (4246, 4246)

# %%
i=5800717





data.loc[data['product_id'] ==i]
# Out:
#                    event_time event_type  product_id   category_id  \
# 496   2019-10-01 16:02:07 UTC       view     5800717  2.053014e+18
# 4122  2019-10-01 07:54:49 UTC       view     5800717  2.053014e+18
# 4589  2019-10-01 13:45:52 UTC       view     5800717  2.053014e+18
# 4594  2019-10-01 13:47:49 UTC       view     5800717  2.053014e+18
# 4596  2019-10-01 13:48:39 UTC       view     5800717  2.053014e+18
# 4609  2019-10-01 13:55:31 UTC       view     5800717  2.053014e+18
# 4634  2019-10-01 14:28:15 UTC       view     5800717  2.053014e+18
# 4649  2019-10-01 17:02:32 UTC       view     5800717  2.053014e+18
# 4651  2019-10-01 17:05:00 UTC       view     5800717  2.053014e+18
# 4652  2019-10-01 17:26:42 UTC       view     5800717  2.053014e+18
#
#                     category_code brand   price    user_id  \
# 496   electronics.audio.subwoofer   NaN  144.15  436339065
# 4122  electronics.audio.subwoofer   NaN  144.15  504435616
# 4589  electronics.audio.subwoofer   NaN  144.15  508506708
# 4594  electronics.audio.subwoofer   NaN  144.15  508506708
# 4596  electronics.audio.subwoofer   NaN  144.15  508506708
# 4609  electronics.audio.subwoofer   NaN  144.15  508506708
# 4634  electronics.audio.subwoofer   NaN  144.15  508506708
# 4649  electronics.audio.subwoofer   NaN  144.15  508506708
# 4651  electronics.audio.subwoofer   NaN  144.15  508506708
# 4652  electronics.audio.subwoofer   NaN  144.15  508506708
#
#                               user_session  interaction
# 496   fdfded7a-607c-4d78-8f9b-d22d8da7e40f            1
# 4122  08fcbdf0-f4f4-4c76-9378-14d355de4887            1
# 4589  511af90a-0ff1-4765-aaf1-e2f1c76792be            1
# 4594  511af90a-0ff1-4765-aaf1-e2f1c76792be            1
# 4596  511af90a-0ff1-4765-aaf1-e2f1c76792be            1
# 4609  511af90a-0ff1-4765-aaf1-e2f1c76792be            1
# 4634  511af90a-0ff1-4765-aaf1-e2f1c76792be            1
# 4649  86b36aec-03ba-4773-8bbf-5234dc64c870            1
# 4651  86b36aec-03ba-4773-8bbf-5234dc64c870            1
# 4652  86b36aec-03ba-4773-8bbf-5234dc64c870            1

# %%
product_names = list(product_matrix.index)
product_ID = product_names.index(i)
product_ID
# Out:
# 1614

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (4246,)

# %%
Recommend = list(product_matrix.index[correlation_product_ID > 0.90])

# Removes the item already bought by the customer
Recommend.remove(i) 
x=Recommend[0:9]

# %%
correlation_product_ID
# Out:
# array([-0.01961152, -0.04142273, -0.0415897 , ...,  0.10852348,
#         0.10852348, -0.03288258])

# %%
data.loc[data['product_id'].isin(x)].head(10)
# Out:
#                    event_time event_type  product_id   category_id  \
# 462   2019-10-01 15:40:17 UTC       view     1480163  2.053014e+18
# 463   2019-10-01 15:41:14 UTC       view     1480163  2.053014e+18
# 464   2019-10-01 15:41:19 UTC       view     1480164  2.053014e+18
# 465   2019-10-01 15:41:43 UTC       view     1480164  2.053014e+18
# 466   2019-10-01 15:41:45 UTC       view     1480163  2.053014e+18
# 526   2019-10-01 16:17:27 UTC       view     2300161  2.053014e+18
# 529   2019-10-01 16:20:21 UTC       view     2300203  2.053014e+18
# 530   2019-10-01 16:22:09 UTC       view     2300203  2.053014e+18
# 531   2019-10-01 16:23:44 UTC       view     2200976  2.053014e+18
# 1062  2019-10-01 03:29:38 UTC       view     2300161  2.053014e+18
#
#                  category_code      brand    price    user_id  \
# 462          computers.desktop       acer   617.00  436339065
# 463          computers.desktop       acer   617.00  436339065
# 464          computers.desktop       acer  1155.50  436339065
# 465          computers.desktop       acer  1155.50  436339065
# 466          computers.desktop       acer   617.00  436339065
# 526   electronics.camera.video      sjcam    58.93  436339065
# 529   electronics.camera.video  panasonic  2435.43  436339065
# 530   electronics.camera.video  panasonic  2435.43  436339065
# 531                        NaN      canon  2571.80  436339065
# 1062  electronics.camera.video      sjcam    64.09  459555560
#
#                               user_session  interaction
# 462   fdfded7a-607c-4d78-8f9b-d22d8da7e40f            1
# 463   fdfded7a-607c-4d78-8f9b-d22d8da7e40f            1
# 464   fdfded7a-607c-4d78-8f9b-d22d8da7e40f            1
# 465   fdfded7a-607c-4d78-8f9b-d22d8da7e40f            1
# 466   fdfded7a-607c-4d78-8f9b-d22d8da7e40f            1
# 526   fdfded7a-607c-4d78-8f9b-d22d8da7e40f            1
# 529   fdfded7a-607c-4d78-8f9b-d22d8da7e40f            1
# 530   fdfded7a-607c-4d78-8f9b-d22d8da7e40f            1
# 531   fdfded7a-607c-4d78-8f9b-d22d8da7e40f            1
# 1062  5b203159-c8e7-4d89-959c-9821d0f9ea94            1
