# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_excel('Sample 5000.xlsx')
data
# Out:
#                     event_time event_type  product_id   category_id  \
# 0      2019-10-01 08:47:35 UTC       view     1001588  2.053014e+18
# 1      2019-10-01 08:48:28 UTC       view     1003535  2.053014e+18
# 2      2019-10-01 17:06:51 UTC       view     4100129  2.053014e+18
# 3      2019-10-01 16:48:28 UTC       view     6400036  2.053014e+18
# 4      2019-10-01 17:07:37 UTC       view     1004870  2.053014e+18
# ...                        ...        ...         ...           ...
# 9996   2019-10-01 16:09:57 UTC       view     6701210  2.053014e+18
# 9997   2019-10-01 16:10:50 UTC       view     6701210  2.053014e+18
# 9998   2019-10-01 11:12:38 UTC       view     3900217  2.053014e+18
# 9999   2019-10-01 11:13:30 UTC       view     1005067  2.053014e+18
# 10000  2019-10-01 11:13:43 UTC       view     1005074  2.053014e+18
#
#                              category_code      brand    price    user_id  \
# 0                   electronics.smartphone    samsung   460.50  244951053
# 1                   electronics.smartphone    samsung   460.50  244951053
# 2                                      NaN       sony   463.02  292071852
# 3                 computers.components.cpu      intel   338.23  295655799
# 4                   electronics.smartphone    samsung   286.84  306087674
# ...                                    ...        ...      ...        ...
# 9996       computers.components.videocards        msi   939.03  512393615
# 9997       computers.components.videocards        msi   939.03  512393615
# 9998   appliances.environment.water_heater  garanterm    90.32  512393698
# 9999                electronics.smartphone    samsung  1209.53  512393698
# 10000               electronics.smartphone    samsung  1235.24  512393698
#
#                                user_session
# 0      91769fdf-461b-4e43-9c73-88a07481b75c
# 1      91769fdf-461b-4e43-9c73-88a07481b75c
# 2      0051531b-c007-442f-88c8-2cbf9537bd02
# 3      eb8f2cea-4c5b-4e00-880f-3bcfa28549ff
# 4      a15f469a-968f-4c8c-8317-6dffed3f5523
# ...                                     ...
# 9996   6b08f33f-53fa-431d-99f6-b06c9b10d6af
# 9997   6b08f33f-53fa-431d-99f6-b06c9b10d6af
# 9998   bac58664-4b1f-414f-a914-afb0caceae36
# 9999   39b68180-94ba-4615-85a8-f8b76f6a84af
# 10000  39b68180-94ba-4615-85a8-f8b76f6a84af
#
# [10001 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_time     10001 non-null  object
#  1   event_type     10001 non-null  object
#  2   product_id     10001 non-null  int64
#  3   category_id    10001 non-null  float64
#  4   category_code  6623 non-null   object
#  5   brand          8595 non-null   object
#  6   price          10001 non-null  float64
#  7   user_id        10001 non-null  int64
#  8   user_session   10001 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 703.3+ KB

# %%
data.describe()
# Out:
#          product_id   category_id         price       user_id
# count  1.000100e+04  1.000100e+04  10001.000000  1.000100e+04
# mean   1.068395e+07  2.056789e+18    290.787317  4.953845e+08
# std    1.141456e+07  1.690892e+16    360.876590  2.920157e+07
# min    1.001588e+06  2.053014e+18      0.000000  2.449511e+08
# 25%    1.201361e+06  2.053014e+18     62.290000  4.886695e+08
# 50%    5.100816e+06  2.053014e+18    161.930000  5.123637e+08
# 75%    1.710038e+07  2.053014e+18    358.050000  5.123790e+08
# max    5.390001e+07  2.172371e+18   2574.070000  5.123937e+08

# %%
data.nunique()
# Out:
# event_time       9076
# event_type          3
# product_id       4246
# category_id       340
# category_code      99
# brand             656
# price            2862
# user_id          1732
# user_session     2512
# dtype: int64

# %%
data.isnull().sum()
# Out:
# event_time          0
# event_type          0
# product_id          0
# category_id         0
# category_code    3378
# brand            1406
# price               0
# user_id             0
# user_session        0
# dtype: int64

# %%
data['product_id'].value_counts()
# Out:
# 1004856     111
# 1004767      84
# 1005115      55
# 1005105      54
# 1002544      53
#            ...
# 2502139       1
# 28100772      1
# 1004142       1
# 18000158      1
# 3900217       1
# Name: product_id, Length: 4246, dtype: int64

# %%
data['user_id'].value_counts()
# Out:
# 512372746    99
# 512377508    98
# 512367874    82
# 512390127    75
# 463570586    74
#              ..
# 512372454     1
# 493542913     1
# 512372569     1
# 493243687     1
# 486765251     1
# Name: user_id, Length: 1732, dtype: int64

# %%
popularproducts=pd.DataFrame(data)

# %%
popular_products = pd.DataFrame(data.groupby("product_id").count()['user_id'].sort_values(ascending=False))
popular_products.rename(columns={"product_id": "count"})
popular_products
# Out:
#             user_id
# product_id
# 1004856         111
# 1004767          84
# 1005115          55
# 1005105          54
# 1002544          53
# ...             ...
# 11200451          1
# 11200504          1
# 11200505          1
# 11400099          1
# 53900007          1
#
# [4246 rows x 1 columns]

# %%
popular_products.head(30).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='product_id'>

# %%
product_matrix=data.pivot_table(index="user_id",columns='product_id',values="interaction",fill_value=0)
product_matrix
# Out:
# product_id  1001588   1002099   1002101   1002102   1002367   1002398   \
# user_id
# 244951053          1         0         0         0         0         0
# 292071852          0         0         0         0         0         0
# 295655799          0         0         0         0         0         0
# 306087674          0         0         0         0         0         0
# 306441847          0         0         0         0         0         0
# ...              ...       ...       ...       ...       ...       ...
# 512393480          0         0         0         0         0         0
# 512393542          0         0         0         0         0         0
# 512393581          0         0         0         0         0         0
# 512393615          0         0         0         0         0         0
# 512393698          0         0         0         0         0         0
#
# product_id  1002482   1002484   1002524   1002532   ...  52900003  52900013  \
# user_id                                             ...
# 244951053          0         0         0         0  ...         0         0
# 292071852          0         0         0         0  ...         0         0
# 295655799          0         0         0         0  ...         0         0
# 306087674          0         0         0         0  ...         0         0
# 306441847          0         0         0         0  ...         0         0
# ...              ...       ...       ...       ...  ...       ...       ...
# 512393480          0         0         0         0  ...         0         0
# 512393542          0         0         0         0  ...         0         0
# 512393581          0         0         0         0  ...         0         0
# 512393615          0         0         0         0  ...         0         0
# 512393698          0         0         0         0  ...         0         0
#
# product_id  52900025  52900026  52900038  52900039  52900050  52900077  \
# user_id
# 244951053          0         0         0         0         0         0
# 292071852          0         0         0         0         0         0
# 295655799          0         0         0         0         0         0
# 306087674          0         0         0         0         0         0
# 306441847          0         0         0         0         0         0
# ...              ...       ...       ...       ...       ...       ...
# 512393480          0         0         0         0         0         0
# 512393542          0         0         0         0         0         0
# 512393581          0         0         0         0         0         0
# 512393615          0         0         0         0         0         0
# 512393698          0         0         0         0         0         0
#
# product_id  52900079  53900007
# user_id
# 244951053          0         0
# 292071852          0         0
# 295655799          0         0
# 306087674          0         0
# 306441847          0         0
# ...              ...       ...
# 512393480          0         0
# 512393542          0         0
# 512393581          0         0
# 512393615          0         0
# 512393698          0         0
#
# [1732 rows x 4246 columns]

# %%
product_matrix.shape
# Out:
# (1732, 4246)

# %%
product_matrix.query('user_id ==512367874').sum(axis=1)
# Out:
# user_id
# 512367874    24
# dtype: int64

# %%
product_matrix=product_matrix.T
product_matrix
# Out:
# user_id     244951053  292071852  295655799  306087674  306441847  315309190  \
# product_id
# 1001588             1          0          0          0          0          0
# 1002099             0          0          0          0          0          0
# 1002101             0          0          0          0          0          0
# 1002102             0          0          0          0          0          0
# 1002367             0          0          0          0          0          0
# ...               ...        ...        ...        ...        ...        ...
# 52900039            0          0          0          0          0          0
# 52900050            0          0          0          0          0          0
# 52900077            0          0          0          0          0          0
# 52900079            0          0          0          0          0          0
# 53900007            0          0          0          0          0          0
#
# user_id     315805600  318145786  321655812  330585300  ...  512393171  \
# product_id                                              ...
# 1001588             0          0          0          0  ...          0
# 1002099             0          0          0          0  ...          0
# 1002101             0          0          0          0  ...          0
# 1002102             0          0          0          0  ...          0
# 1002367             0          0          0          0  ...          0
# ...               ...        ...        ...        ...  ...        ...
# 52900039            0          0          0          0  ...          0
# 52900050            0          0          0          0  ...          0
# 52900077            0          0          0          0  ...          0
# 52900079            0          0          0          0  ...          0
# 53900007            0          0          0          0  ...          0
#
# user_id     512393323  512393343  512393366  512393426  512393480  512393542  \
# product_id
# 1001588             0          0          0          0          0          0
# 1002099             0          0          0          0          0          0
# 1002101             0          0          0          0          0          0
# 1002102             0          0          0          0          0          0
# 1002367             0          0          0          0          0          0
# ...               ...        ...        ...        ...        ...        ...
# 52900039            0          0          0          0          0          0
# 52900050            0          0          0          0          0          0
# 52900077            0          0          0          0          0          0
# 52900079            0          0          0          0          0          0
# 53900007            0          0          0          0          0          0
#
# user_id     512393581  512393615  512393698
# product_id
# 1001588             0          0          0
# 1002099             0          0          0
# 1002101             0          0          0
# 1002102             0          0          0
# 1002367             0          0          0
# ...               ...        ...        ...
# 52900039            0          0          0
# 52900050            0          0          0
# 52900077            0          0          0
# 52900079            0          0          0
# 53900007            0          0          0
#
# [4246 rows x 1732 columns]

# %%
product_matrix.shape
# Out:
# (4246, 1732)

# %%
import sklearn
from sklearn.decomposition import TruncatedSVD
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(product_matrix)
decomposed_matrix.shape
# Out:
# (4246, 10)

# %%
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (4246, 4246)

# %%
i=4600598




data.loc[data['product_id'] ==i]
# Out:
#                   event_time event_type  product_id   category_id  \
# 100  2019-10-01 16:39:20 UTC       view     4600598  2.053014e+18
#
#                      category_code  brand   price    user_id  \
# 100  appliances.kitchen.dishwasher  bosch  671.81  376216570
#
#                              user_session  interaction
# 100  ab846129-c75f-4da7-adf5-21857b1c87f4            1

# %%
product_names = list(product_matrix.index)
product_ID = product_names.index(i)
product_ID
# Out:
# 1329

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (4246,)

# %%
Recommend = list(product_matrix.index[correlation_product_ID > 0.90])

# Removes the item already bought by the customer
Recommend.remove(i) 
x=Recommend[0:9]

# %%
data.loc[data['product_id'].isin(x)].head(10)
# Out:
#                    event_time event_type  product_id   category_id  \
# 102   2019-10-01 16:42:42 UTC       view     4600543  2.053014e+18
# 103   2019-10-01 16:43:48 UTC       view     4600129  2.053014e+18
# 104   2019-10-01 16:46:08 UTC       view     4600549  2.053014e+18
# 338   2019-10-01 17:14:32 UTC       view     1003860  2.053014e+18
# 1090  2019-10-01 14:44:27 UTC       view     1307355  2.053014e+18
# 1091  2019-10-01 14:48:49 UTC       view     1306419  2.053014e+18
# 1092  2019-10-01 13:49:49 UTC       view     1003860  2.053014e+18
# 1094  2019-10-01 13:51:19 UTC       view     1003860  2.053014e+18
# 1096  2019-10-01 13:54:23 UTC       view     1801831  2.053014e+18
# 1375  2019-10-01 09:00:51 UTC       view     3900815  2.053014e+18
#
#                             category_code    brand    price    user_id  \
# 102         appliances.kitchen.dishwasher     beko   511.95  376216570
# 103         appliances.kitchen.dishwasher    bosch   606.87  376216570
# 104         appliances.kitchen.dishwasher     beko   450.43  376216570
# 338                electronics.smartphone  samsung   223.43  428058980
# 1090                   computers.notebook     asus   684.67  460178633
# 1091                   computers.notebook     asus  1206.30  460178633
# 1092               electronics.smartphone  samsung   223.43  460250008
# 1094               electronics.smartphone  samsung   223.43  460250008
# 1096                 electronics.video.tv  shivaki   218.77  460250008
# 1375  appliances.environment.water_heater  ariston   133.81  467913597
#
#                               user_session  interaction
# 102   ab846129-c75f-4da7-adf5-21857b1c87f4            1
# 103   ab846129-c75f-4da7-adf5-21857b1c87f4            1
# 104   ab846129-c75f-4da7-adf5-21857b1c87f4            1
# 338   bdc3eec3-e9d5-4b6a-8217-cbcc7b562e33            1
# 1090  1444f1d0-cc78-4dc5-9d87-66f7be5a33d4            1
# 1091  198a4a5e-3fe0-4b59-891d-d91f9f1085b9            1
# 1092  e36d50ec-4647-4522-826e-6fb08d730a81            1
# 1094  e36d50ec-4647-4522-826e-6fb08d730a81            1
# 1096  e36d50ec-4647-4522-826e-6fb08d730a81            1
# 1375  30173061-41d9-46c5-b1d0-4fd99bec197f            1
